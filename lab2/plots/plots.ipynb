# %%
import numpy as np
from matplotlib import pyplot as plt
import os

directory = "../app/rpts"
files = os.listdir(directory)


for file in files:
    #file = files[0]

    from numpy import genfromtxt

    my_data = genfromtxt(directory + "/" + file, delimiter=',')
    freqs = file.split('.')[0].split('_')[-2:]
    #print(freqs)
    x = [i[0] for i in my_data[1:]]
    
    y = [i[1] if i[1] < 2000 else 1500 for i in my_data[1:]]

    #print(x)
    #print(y)
    plt.title(file)
    plt.plot(x, y, 'or')


    plt.show()


directory = "../app"
files = [i for i in os.listdir(directory ) if 'csv' in i ]
print(files)

for file in files:
    #file = files[0]

    from numpy import genfromtxt

    my_data = genfromtxt(directory + "/" + file, delimiter=',')
    freqs = file.split('.')[0].split('_')[-2:]
    #print(freqs)
    x = [i[0] for i in my_data[1:]]
    
    #y = [i[1] if i[1] < 2000 else 1500 for i in my_data[1:]]
    y = [i[1] for i in my_data[1:]]

    #print(x)
    #print(y)
    plt.title(file)
    plt.plot(x, y, 'or')


    plt.show()
# Out:
# ['interrupt_latency_10000.csv.noload', 'interrupt_latency_10000.csv']
